# %% [markdown]
# # Блок 3
# ## Задание 3.1

# %%
import pandas as pd 
heights = [188, 172, 187, 161, 183, 172, 185, 163, 173, 183, 174, 174, 175,
178, 183, 195, 178, 173, 174, 183, 174, 181, 162, 180, 170, 175, 182, 180, 183,
178, 182, 188, 175, 179, 184, 193, 182, 183, 175, 185, 182, 183, 156, 185, 199] 
weights = [86, 71, 89, 64, 83, 71, 86, 68, 73, 84, 73, 72, 75, 78, 85, 93, 78,
70, 74, 80, 83, 82, 68, 80, 73, 78, 82, 81, 83, 79, 82, 86, 76, 77, 80, 103,
82, 83, 77, 89, 80, 85, 82, 85, 110] 
ages = [58, 61, 54, 54, 58, 57, 63, 54, 37, 51, 34, 26, 50, 48, 45, 52, 56,
46, 54, 28, 52, 47, 55, 55, 54, 42, 51, 56, 55, 51, 54, 32, 21, 62, 43, 55,
56, 61, 53, 22, 64, 45, 54, 47, 38] 

df= pd.DataFrame ({"heights" : heights, "weights" : weights , "ages" : ages}) 
#print (df)
df=(df.loc [0:40])
print (df)
# Out:
#     heights  weights  ages
# 0       188       86    58
# 1       172       71    61
# 2       187       89    54
# 3       161       64    54
# 4       183       83    58
# 5       172       71    57
# 6       185       86    63
# 7       163       68    54
# 8       173       73    37
# 9       183       84    51
# 10      174       73    34
# 11      174       72    26
# 12      175       75    50
# 13      178       78    48
# 14      183       85    45
# 15      195       93    52
# 16      178       78    56
# 17      173       70    46
# 18      174       74    54
# 19      183       80    28
# 20      174       83    52
# 21      181       82    47
# 22      162       68    55
# 23      180       80    55
# 24      170       73    54
# 25      175       78    42
# 26      182       82    51
# 27      180       81    56
# 28      183       83    55
# 29      178       79    51
# 30      182       82    54
# 31      188       86    32
# 32      175       76    21
# 33      179       77    62
# 34      184       80    43
# 35      193      103    55
# 36      182       82    56
# 37      183       83    61
# 38      175       77    53
# 39      185       89    22
# 40      182       80    64

# %% [markdown]
# ## Задание 3.2

# %%
import pandas as pd 
heights = [188, 172, 187, 161, 183, 172, 185, 163, 173, 183, 174, 174, 175,
178, 183, 195, 178, 173, 174, 183, 174, 181, 162, 180, 170, 175, 182, 180, 183,
178, 182, 188, 175, 179, 184, 193, 182, 183, 175, 185, 182, 183, 156, 185, 199] 
weights = [86, 71, 89, 64, 83, 71, 86, 68, 73, 84, 73, 72, 75, 78, 85, 93, 78,
70, 74, 80, 83, 82, 68, 80, 73, 78, 82, 81, 83, 79, 82, 86, 76, 77, 80, 103,
82, 83, 77, 89, 80, 85, 82, 85, 110] 
ages = [58, 61, 54, 54, 58, 57, 63, 54, 37, 51, 34, 26, 50, 48, 45, 52, 56,
46, 54, 28, 52, 47, 55, 55, 54, 42, 51, 56, 55, 51, 54, 32, 21, 62, 43, 55,
56, 61, 53, 22, 64, 45, 54, 47, 38] 

df= pd.DataFrame ({"heights" : heights, "weights" : weights , "ages" : ages}) 
#print (df)
df=(df.loc [0:40])

df_new = df[df["heights"] > 180] ["heights"]

#f_n = df[['heights',"ages"]][0:20] второй метод, сокращенный через лок

#df_n = df.loc[:5,["ages"]]  можно еще iloc


print (df_new)
# Out:
# 0     188
# 2     187
# 4     183
# 6     185
# 9     183
# 14    183
# 15    195
# 19    183
# 21    181
# 26    182
# 28    183
# 30    182
# 31    188
# 34    184
# 35    193
# 36    182
# 37    183
# 39    185
# 40    182
# Name: heights, dtype: int64

# %% [markdown]
# ## Задание 3.3

# %%
import pandas as pd 
heights = [188, 172, 187, 161, 183, 172, 185, 163, 173, 183, 174, 174, 175,
178, 183, 195, 178, 173, 174, 183, 174, 181, 162, 180, 170, 175, 182, 180, 183,
178, 182, 188, 175, 179, 184, 193, 182, 183, 175, 185, 182, 183, 156, 185, 199] 
weights = [86, 71, 89, 64, 83, 71, 86, 68, 73, 84, 73, 72, 75, 78, 85, 93, 78,
70, 74, 80, 83, 82, 68, 80, 73, 78, 82, 81, 83, 79, 82, 86, 76, 77, 80, 103,
82, 83, 77, 89, 80, 85, 82, 85, 110] 
ages = [58, 61, 54, 54, 58, 57, 63, 54, 37, 51, 34, 26, 50, 48, 45, 52, 56,
46, 54, 28, 52, 47, 55, 55, 54, 42, 51, 56, 55, 51, 54, 32, 21, 62, 43, 55,
56, 61, 53, 22, 64, 45, 54, 47, 38] 

df= pd.DataFrame ({"heights" : heights, "weights" : weights , "ages" : ages}) 
#print (df)
df=(df.loc [0:40])

f_n = df[df["weights"] < 80] ["weights"]
print (f_n.shape)
# Out:
# (19,)

# %% [markdown]
# ## Задание 3.4

# %%
import pandas as pd 
heights = [188, 172, 187, 161, 183, 172, 185, 163, 173, 183, 174, 174, 175,
178, 183, 195, 178, 173, 174, 183, 174, 181, 162, 180, 170, 175, 182, 180, 183,
178, 182, 188, 175, 179, 184, 193, 182, 183, 175, 185, 182, 183, 156, 185, 199] 
weights = [86, 71, 89, 64, 83, 71, 86, 68, 73, 84, 73, 72, 75, 78, 85, 93, 78,
70, 74, 80, 83, 82, 68, 80, 73, 78, 82, 81, 83, 79, 82, 86, 76, 77, 80, 103,
82, 83, 77, 89, 80, 85, 82, 85, 110] 
ages = [58, 61, 54, 54, 58, 57, 63, 54, 37, 51, 34, 26, 50, 48, 45, 52, 56,
46, 54, 28, 52, 47, 55, 55, 54, 42, 51, 56, 55, 51, 54, 32, 21, 62, 43, 55,
56, 61, 53, 22, 64, 45, 54, 47, 38] 

df= pd.DataFrame ({"heights" : heights, "weights" : weights , "ages" : ages}) 
#print (df)
df=(df.loc [0:40])

f_n1 = df[(df["ages"] > 30) & (df["ages"] < 50) ]["ages"]
print (f_n1)

f_n = df[(df["ages"] > 30) & (df["ages"] < 50) ]["ages"].count ()
print (f_n)
# Out:
# 8     37
# 10    34
# 13    48
# 14    45
# 17    46
# 21    47
# 25    42
# 31    32
# 34    43
# Name: ages, dtype: int64
# 9

# %% [markdown]
# ## Задание 3.5

# %%
import pandas as pd 
heights = [188, 172, 187, 161, 183, 172, 185, 163, 173, 183, 174, 174, 175,
178, 183, 195, 178, 173, 174, 183, 174, 181, 162, 180, 170, 175, 182, 180, 183,
178, 182, 188, 175, 179, 184, 193, 182, 183, 175, 185, 182, 183, 156, 185, 199] 
weights = [86, 71, 89, 64, 83, 71, 86, 68, 73, 84, 73, 72, 75, 78, 85, 93, 78,
70, 74, 80, 83, 82, 68, 80, 73, 78, 82, 81, 83, 79, 82, 86, 76, 77, 80, 103,
82, 83, 77, 89, 80, 85, 82, 85, 110] 
ages = [58, 61, 54, 54, 58, 57, 63, 54, 37, 51, 34, 26, 50, 48, 45, 52, 56,
46, 54, 28, 52, 47, 55, 55, 54, 42, 51, 56, 55, 51, 54, 32, 21, 62, 43, 55,
56, 61, 53, 22, 64, 45, 54, 47, 38] 

df= pd.DataFrame ({"heights" : heights, "weights" : weights , "ages" : ages}) 
#print (df)
df=(df.loc [0:40])

fn = df[(df["heights"] > 170) & (df["weights"] > 80) ]
print (fn)

print(fn.describe())
# Out:
#     heights  weights  ages
# 0       188       86    58
# 2       187       89    54
# 4       183       83    58
# 6       185       86    63
# 9       183       84    51
# 14      183       85    45
# 15      195       93    52
# 20      174       83    52
# 21      181       82    47
# 26      182       82    51
# 27      180       81    56
# 28      183       83    55
# 30      182       82    54
# 31      188       86    32
# 35      193      103    55
# 36      182       82    56
# 37      183       83    61
# 39      185       89    22
#           heights     weights       ages
# count   18.000000   18.000000  18.000000
# mean   184.277778   85.666667  51.222222
# std      4.762668    5.335784   9.991500
# min    174.000000   81.000000  22.000000
# 25%    182.000000   82.250000  51.000000
# 50%    183.000000   83.500000  54.000000
# 75%    186.500000   86.000000  56.000000
# max    195.000000  103.000000  63.000000
