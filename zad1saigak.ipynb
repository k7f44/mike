# %% [markdown]
# ### Задание 1

# %%
import pandas as pd 
import matplotlib.pyplot as plt  
import numpy as np

def plot (x_data,y_data):
        fig = plt.figure() 
        ax = plt.axes() 
        ax.plot(x_data, y_data) 

        ax.grid( linewidth=0.8,
                linestyle='--')
        plt.plot(x_data, y_data, linewidth ='1', color='r')
        plt.show()



x = np.linspace(0, 10, 1000) 
y = (np.sin(x_data)/10)+0.9
plot(x,y)
plt.show()

f=1.9
p=3.14
w=2*p*f
y=(0.1*np.sin(w*x)+0.9)
plot(x,y)


r= 0.007*y
plot(x,r)



p1=120
p2=110
vyaz=5
l=133*0.001
Q=(3.14*r**4*(p1-p2))/(8*vyaz*l)
plot(x,Q)

print(np.mean(Q))
# Out:
# 9.642462857460477e-09
